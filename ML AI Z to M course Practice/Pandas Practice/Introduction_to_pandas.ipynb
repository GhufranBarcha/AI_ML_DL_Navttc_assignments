# %% [markdown]
# # Introduction to pandas
#  importing pandas

# %%
import pandas as pd

# %%
#Make a Series

series =pd.Series(["car","gas","hello","jiu"])

# %%
series
# Out:
# 0      car
# 1      gas
# 2    hello
# 3      jiu
# dtype: object

# %%
colors =pd.Series(["blue","green","red","white"])

# %%
colors
# Out:
# 0     blue
# 1    green
# 2      red
# 3    white
# dtype: object

# %%
#making a dataframe

df= pd.DataFrame({"series": 1, "cloes":[1,2,3]})

# %%
df
# Out:
#    series  cloes
# 0       1      1
# 1       1      2
# 2       1      3

# %% [markdown]
# # importing a csv file as dataframe

# %%
df=pd.read_csv("car-sales.csv")

# %%
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
df.to_csv("car_sales_dow.csv",index =False)

# %%
df1 = pd.read_csv("car_sales_dow.csv")

# %%
df1
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# # Some Basic function and attributes applied on data

# %%
# Describe function calculate basic math function
df1.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
#dtypes tell us each coloum type
df1.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
#mean tell us mean of each numeric  coloum type
df1.mean()
# Out:
# C:\Users\Barcha\AppData\Local\Temp\ipykernel_7948\414057558.py:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.mean()
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
#coloums give us name of coloum
coloums = df1.columns
coloums[0:]
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
#index give us how many rows are there
df1.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
#info give us i
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
df1.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
df1.median()
# Out:
# C:\Users\Barcha\AppData\Local\Temp\ipykernel_7948\905090672.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df1.median()
# Odometer (KM)    57369.0
# Doors                4.0
# dtype: float64

# %%
df1['Make']
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %% [markdown]
# ## acessing and slicing

# %%
df1
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
df1.head(3)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
df1.tail(2)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
df1
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
#iloc and loc
data = df1[df1["Colour"] == 11179  ]
data.iloc[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[26], line 3
#       1 #iloc and loc
#       2 data = df1[df1["Colour"] == 11179  ]
# ----> 3 data.iloc[0]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1625, in _iLocIndexer._getitem_axis(self, key, axis)
#    1622     raise TypeError("Cannot index by location index with a non-integer key")
#    1624 # validate the location
# -> 1625 self._validate_integer(key, axis)
#    1627 return self.obj._ixs(key, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1557, in _iLocIndexer._validate_integer(self, key, axis)
# ...

# %%
data = df1[df1["Colour"] == "Blue" ]
print(data)
data.loc[[2],['Make','Colour']]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 2  Toyota   Blue          32549      3  $7,000.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
#      Make Colour
# 2  Toyota   Blue

# %%
selected_data = data.loc[:, ["Make", "Colour"]]
selected_data
# Out:
#      Make Colour
# 2  Toyota   Blue
# 6   Honda   Blue
# 7   Honda   Blue

# %%
df1

# %%
pd.crosstab(df1['Make'], df1["Colour"])
# Out:
# Colour  Black  Blue  Green  Red  White
# Make
# BMW         1     0      0    0      0
# Honda       0     2      0    1      0
# Nissan      0     0      0    0      2
# Toyota      0     1      1    0      2

# %%
df1.groupby(["Make"]).sum()

# %%
df1["Odometer (KM)"].plot()

# %%
df1["Odometer (KM)"].hist()

# %%
df1["Odometer (KM)"].plot(kind='bar')

# %%
df2=df1["Price"].str.replace('[\$\,]','').astype('f')
df2.plot()

# %% [markdown]
# # Missing data manipulation

# %%
df1['Make']=df1['Make'].str.lower()

# %%
df1
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  toyota  White         150043      4   $4,000.00
# 1   honda    Red          87899      4   $5,000.00
# 2  toyota   Blue          32549      3   $7,000.00
# 3     bmw  Black          11179      5  $22,000.00
# 4  nissan  White         213095      4   $3,500.00
# 5  toyota  Green          99213      4   $4,500.00
# 6   honda   Blue          45698      4   $7,500.00
# 7   honda   Blue          54738      4   $7,000.00
# 8  toyota  White          60000      4   $6,250.00
# 9  nissan  White          31600      4   $9,700.00

# %%
df2 = pd.read_csv("009 car-sales-missing-data.csv")
df2
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
df2.fillna(0,inplace=True)

# %%
df2
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       0.0    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       0.0    4.0   $4,500
# 6   Honda      0       0.0    4.0   $7,500
# 7   Honda   Blue       0.0    4.0        0
# 8  Toyota  White   60000.0    0.0        0
# 9       0  White   31600.0    4.0   $9,700

# %%
df2.dropna(inplace=True)

# %%
df2
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
df2 = pd.read_csv("009 car-sales-missing-data.csv")
df2
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
seats_coloums = pd.Series([1,1,1,1,23,3])
df2["seates"] = seats_coloums

# %%
df2["seates"].fillna(5,inplace=True)

# %%
df2["Odometer"].fillna(df2["Odometer"].mean(),inplace=True)

# %%
 df2
# Out:
#      Make Colour       Odometer  Doors    Price  seates
# 0  Toyota  White  150043.000000    4.0   $4,000     1.0
# 1   Honda    Red   87899.000000    4.0   $5,000     1.0
# 2  Toyota   Blue   92302.666667    3.0   $7,000     1.0
# 3     BMW  Black   11179.000000    5.0  $22,000     1.0
# 4  Nissan  White  213095.000000    4.0   $3,500    23.0
# 5  Toyota  Green   92302.666667    4.0   $4,500     3.0
# 6   Honda    NaN   92302.666667    4.0   $7,500     5.0
# 7   Honda   Blue   92302.666667    4.0      NaN     5.0
# 8  Toyota  White   60000.000000    NaN      NaN     5.0
# 9     NaN  White   31600.000000    4.0   $9,700     5.0

# %%
df2["fuel used"] = df2["Odometer"]/df2["seates"] *100

# %%
df2
# Out:
#      Make Colour       Odometer  Doors    Price  seates     fuel used
# 0  Toyota  White  150043.000000    4.0   $4,000     1.0  1.500430e+07
# 1   Honda    Red   87899.000000    4.0   $5,000     1.0  8.789900e+06
# 2  Toyota   Blue   92302.666667    3.0   $7,000     1.0  9.230267e+06
# 3     BMW  Black   11179.000000    5.0  $22,000     1.0  1.117900e+06
# 4  Nissan  White  213095.000000    4.0   $3,500    23.0  9.265000e+05
# 5  Toyota  Green   92302.666667    4.0   $4,500     3.0  3.076756e+06
# 6   Honda    NaN   92302.666667    4.0   $7,500     5.0  1.846053e+06
# 7   Honda   Blue   92302.666667    4.0      NaN     5.0  1.846053e+06
# 8  Toyota  White   60000.000000    NaN      NaN     5.0  1.200000e+06
# 9     NaN  White   31600.000000    4.0   $9,700     5.0  6.320000e+05

# %%
df2.drop("Colour",axis=1)
# Out:
#      Make       Odometer  Doors    Price  seates     fuel used
# 0  Toyota  150043.000000    4.0   $4,000     1.0  1.500430e+07
# 1   Honda   87899.000000    4.0   $5,000     1.0  8.789900e+06
# 2  Toyota   92302.666667    3.0   $7,000     1.0  9.230267e+06
# 3     BMW   11179.000000    5.0  $22,000     1.0  1.117900e+06
# 4  Nissan  213095.000000    4.0   $3,500    23.0  9.265000e+05
# 5  Toyota   92302.666667    4.0   $4,500     3.0  3.076756e+06
# 6   Honda   92302.666667    4.0   $7,500     5.0  1.846053e+06
# 7   Honda   92302.666667    4.0      NaN     5.0  1.846053e+06
# 8  Toyota   60000.000000    NaN      NaN     5.0  1.200000e+06
# 9     NaN   31600.000000    4.0   $9,700     5.0  6.320000e+05

# %% [markdown]
# ##

# %%
df2
# Out:
#      Make Colour       Odometer  Doors    Price  seates     fuel used
# 0  Toyota  White  150043.000000    4.0   $4,000     1.0  1.500430e+07
# 1   Honda    Red   87899.000000    4.0   $5,000     1.0  8.789900e+06
# 2  Toyota   Blue   92302.666667    3.0   $7,000     1.0  9.230267e+06
# 3     BMW  Black   11179.000000    5.0  $22,000     1.0  1.117900e+06
# 4  Nissan  White  213095.000000    4.0   $3,500    23.0  9.265000e+05
# 5  Toyota  Green   92302.666667    4.0   $4,500     3.0  3.076756e+06
# 6   Honda    NaN   92302.666667    4.0   $7,500     5.0  1.846053e+06
# 7   Honda   Blue   92302.666667    4.0      NaN     5.0  1.846053e+06
# 8  Toyota  White   60000.000000    NaN      NaN     5.0  1.200000e+06
# 9     NaN  White   31600.000000    4.0   $9,700     5.0  6.320000e+05

# %%
shuffle = df2.sample(frac=1)
shuffle
# Out:
#      Make Colour       Odometer  Doors    Price  seates     fuel used
# 2  Toyota   Blue   92302.666667    3.0   $7,000     1.0  9.230267e+06
# 4  Nissan  White  213095.000000    4.0   $3,500    23.0  9.265000e+05
# 0  Toyota  White  150043.000000    4.0   $4,000     1.0  1.500430e+07
# 5  Toyota  Green   92302.666667    4.0   $4,500     3.0  3.076756e+06
# 3     BMW  Black   11179.000000    5.0  $22,000     1.0  1.117900e+06
# 6   Honda    NaN   92302.666667    4.0   $7,500     5.0  1.846053e+06
# 7   Honda   Blue   92302.666667    4.0      NaN     5.0  1.846053e+06
# 1   Honda    Red   87899.000000    4.0   $5,000     1.0  8.789900e+06
# 8  Toyota  White   60000.000000    NaN      NaN     5.0  1.200000e+06
# 9     NaN  White   31600.000000    4.0   $9,700     5.0  6.320000e+05

# %%
shuffle.reset_index(drop=True,inplace=True)

# %%
shuffle
# Out:
#      Make Colour       Odometer  Doors    Price  seates     fuel used
# 0  Toyota   Blue   92302.666667    3.0   $7,000     1.0  9.230267e+06
# 1  Nissan  White  213095.000000    4.0   $3,500    23.0  9.265000e+05
# 2  Toyota  White  150043.000000    4.0   $4,000     1.0  1.500430e+07
# 3  Toyota  Green   92302.666667    4.0   $4,500     3.0  3.076756e+06
# 4     BMW  Black   11179.000000    5.0  $22,000     1.0  1.117900e+06
# 5   Honda    NaN   92302.666667    4.0   $7,500     5.0  1.846053e+06
# 6   Honda   Blue   92302.666667    4.0      NaN     5.0  1.846053e+06
# 7   Honda    Red   87899.000000    4.0   $5,000     1.0  8.789900e+06
# 8  Toyota  White   60000.000000    NaN      NaN     5.0  1.200000e+06
# 9     NaN  White   31600.000000    4.0   $9,700     5.0  6.320000e+05

# %%
df["Odometer"] = df["Odometer"].apply(lamda x: x/1.36)
# Out:
#   Cell In[103], line 1
#     df["Odometer"] = df["Odometer"].apply(lamda x: x/1.36)
#                                           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
df1 = shuffle.drop('Make',axis =1)

# %%
df1
# Out:
#   Colour       Odometer  Doors    Price  seates     fuel used
# 0   Blue   92302.666667    3.0   $7,000     1.0  9.230267e+06
# 1  White  213095.000000    4.0   $3,500    23.0  9.265000e+05
# 2  White  150043.000000    4.0   $4,000     1.0  1.500430e+07
# 3  Green   92302.666667    4.0   $4,500     3.0  3.076756e+06
# 4  Black   11179.000000    5.0  $22,000     1.0  1.117900e+06
# 5    NaN   92302.666667    4.0   $7,500     5.0  1.846053e+06
# 6   Blue   92302.666667    4.0      NaN     5.0  1.846053e+06
# 7    Red   87899.000000    4.0   $5,000     1.0  8.789900e+06
# 8  White   60000.000000    NaN      NaN     5.0  1.200000e+06
# 9  White   31600.000000    4.0   $9,700     5.0  6.320000e+05

# %%
conda install -c conda-forge black
# Out:
# Retrieving notices: ...working... done
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.3.1
#   latest version: 23.5.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.5.0
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\Barcha\anaconda3
#
#   added / updated specs:
#     - black
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     black-23.7.0               |  py310h5588dad_1         283 KB  conda-forge
#     ca-certificates-2023.5.7   |       h56e8100_0         145 KB  conda-forge
#     certifi-2023.5.7           |     pyhd8ed1ab_0         149 KB  conda-forge
# ...
